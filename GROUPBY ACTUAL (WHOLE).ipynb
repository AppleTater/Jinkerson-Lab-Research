# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import median
import re
import sys

data = pd.read_csv('TAG Data.csv')

# %% [markdown]
# ## Order 'gene' alphabetically

# %%
data = pd.read_csv('TAG Data.csv')

data = data[['IB' , 'gene' , 'R5-S#11-HLG_WHOLE_normalized_reads' , 'R5-S#11-ALL_WHOLE_normalized_reads']]
data ['Ratios: HLG / ALL (Whole)'] = data ['R5-S#11-HLG_WHOLE_normalized_reads'] / data['R5-S#11-ALL_WHOLE_normalized_reads']

data = data.sort_values('gene')
data
# Out:
#                              IB           gene  \
# 149875   GAACCCTGGAAATTGCGTCAAT  Cre01.g000017
# 110340   GATTTCTCCTGGGGGATATGAG  Cre01.g000017
# 155091   ACGGGGCCTGGGTCGAGATAAC  Cre01.g000017
# 151724   AGGTAGGCACTCATAAGGCGCA  Cre01.g000017
# 119164   GCGTCGCGCTACCTCGTCGTAC  Cre01.g000017
# 73615    GGGGGGCAATTAGACCTCATTA  Cre01.g000017
# 161737   CCCGGCTCGTTGGGTGGCAATG  Cre01.g000017
# 128716   GCGCTGGGCTCGCACCGCGAAA  Cre01.g000017
# 27574    CGGACCGGACTACTTGGAGGAA  Cre01.g000033
# 68558    GACAAATCTGTTTTCACAGACA  Cre01.g000050
# 60043     CGGACATAGACGGCCGACGAG  Cre01.g000050
# 168103   CAAAAGGAAACTGGCGAGTCTA  Cre01.g000050
# 23890    TGGGTATCTATGGCTACAGAGT  Cre01.g000050
# 118812   CACCCGGTTTCAATCGGGCTAG  Cre01.g000100
# 105246   GAGTCTCATGGCTATTCTGTCG  Cre01.g000100
# 122806   CTTGGGCGTTGTTCCCCTTACG  Cre01.g000100
# 130558   TTAGTAATGCTCACAACTATGT  Cre01.g000100
# 18136    GGGTCGGCACGTCGATGCCACA  Cre01.g000100
# 58049   GCGTTAATGTGGGGGGGCATCGA  Cre01.g000100
# 90851    GCAGTCTTGAGTTGTTAGACGT  Cre01.g000150
# 86386    GAGTGTCGGGCAATTAGTACGG  Cre01.g000200
# 62669    GGCTTTTTCCTAGGTGTGGTTT  Cre01.g000200
# 3901     GTTCCGGAACGGAAGGTACGCG  Cre01.g000200
# 114325   CTCCCGTGAACTCGCAGCCGGG  Cre01.g000200
# 60526    TAACTTGCTGTACCGGGTTAAT  Cre01.g000200
# 93701    CTCTCCGGCCAGGAGAGTGCAA  Cre01.g000200
# 46982     GTGTTTGGCTACGTGCGGACT  Cre01.g000200
# 81676    TGGGACTAGCGCCGGGGTTCGG  Cre01.g000200
# 58307    GTCGGACGTCACTCATCTGGGT  Cre01.g000200
# 172464  TGGCCGGAAAGAACTGTGAGGAG  Cre01.g000200
# ...                         ...            ...
# 97863    TCGGACGATACTGTTACGCCCA  unknown_chrom
# 142874   TACACTTCTTGAGGCCGGTTGT  unknown_chrom
# 142870   CGTCTGTTTTTGCTGGTTTAGT  unknown_chrom
# 24535    GCCATCGGGGAACGTACGTCCG  unknown_chrom
# 67865    TCTGTTCCGACATATTGGCCTC  unknown_chrom
# 67858    GTAACCAGCGGCGCGGTTGCGA  unknown_chrom
# 24541    CACGTTGTGATAGGTACAGTTC  unknown_chrom
# 142853   CGAAAAGCTTGCTTAGGAATAT  unknown_chrom
# 142850    AAAATGCGCGATACGGTAGCC  unknown_chrom
# 142848   CCTGGAAACCGGGGTCTTGGGG  unknown_chrom
# 142846   CTGCTGCGAAATCGGCCTCGCG  unknown_chrom
# 67855    GGGGCTAAGCGTTAGTCGCCCG  unknown_chrom
# 24553    GCTACGGGACTCGTGCCTCACC  unknown_chrom
# 142735   GCTGTGATTCCCCCGTGGCCTA  unknown_chrom
# 24559    CACTCTCGTGTCAAAGTTTATT  unknown_chrom
# 142833   TAAGGGAGGGTTGCCTAGGAGG  unknown_chrom
# 142832   CTTTGGGTGACAGACTAAAAGA  unknown_chrom
# 142830   CGCCACGAAGGCGGCTTGGCAG  unknown_chrom
# 97877    CTTACATTTCGAGATCAATCGG  unknown_chrom
# 97879     ACTTGAGGACGTCCTGAGTGC  unknown_chrom
# 142820    CTCTGAGGGCCGCAACAGTCG  unknown_chrom
# 24571    TGGTGCGCGGTCTAGGAAGCGG  unknown_chrom
# 142818   GGGTCAATCGGAGAAGGGGGCG  unknown_chrom
# 142817    TTGTGATCGCTATCTAGCACT  unknown_chrom
# 24574    TTGGGTAGGGTGGCAATAAGTG  unknown_chrom
# 142811   GGAAGCACAGGAGCACGGGCAA  unknown_chrom
# 142809   GAGAGTGCACCACGGATCCTTT  unknown_chrom
# 67838    GGTGTTAGACGCATCCCCCCGG  unknown_chrom
# 67852    TGACGCCGGTGCCTTGGCGCAG  unknown_chrom
# 143062    TGTAGTTCCTGGCGTTTCAAA  unknown_chrom
#
#         R5-S#11-HLG_WHOLE_normalized_reads  \
# 149875                             986.977
# 110340                               0.000
# 155091                              12.818
# 151724                              64.089
# 119164                               0.000
# 73615                                0.000
# 161737                              12.818
# 128716                               0.000
# 27574                                0.000
# 68558                             1695.379
# 60043                                0.000
# 168103                               0.000
# 23890                               26.490
# 118812                               0.000
# 105246                             264.903
# 122806                               0.000
# 130558                               0.000
# 18136                               12.818
# 58049                                0.000
# 90851                               26.490
# 86386                             2702.010
# 62669                                0.000
# 3901                                 0.000
# 114325                              12.818
# 60526                             1324.515
# 93701                                0.000
# 46982                             1086.102
# 81676                                0.000
# 58307                                0.000
# 172464                               0.000
# ...                                    ...
# 97863                                0.000
# 142874                               0.000
# 142870                              26.490
# 24535                             3896.637
# 67865                               26.490
# 67858                             1115.156
# 24541                                0.000
# 142853                               0.000
# 142850                               0.000
# 142848                               0.000
# 142846                               0.000
# 67855                             1576.600
# 24553                             1774.849
# 142735                              26.490
# 24559                                0.000
# 142833                               0.000
# 142832                            1112.592
# 142830                              12.818
# 97877                                0.000
# 97879                               12.818
# 142820                              12.818
# 24571                                0.000
# 142818                             781.891
# 142817                               0.000
# 24574                             6145.747
# 142811                            7639.460
# 142809                              26.490
# 67838                               26.490
# 67852                               26.490
# 143062                               0.000
#
#         R5-S#11-ALL_WHOLE_normalized_reads  Ratios: HLG / ALL (Whole)
# 149875                             969.722                   1.017794
# 110340                               0.000                        NaN
# 155091                            3438.106                   0.003728
# 151724                            1002.781                   0.063911
# 119164                            2848.559                   0.000000
# 73615                              536.527                   0.000000
# 161737                               0.000                        inf
# 128716                               0.000                        NaN
# 27574                              369.156                   0.000000
# 68558                              529.276                   3.203204
# 60043                              837.487                   0.000000
# 168103                               0.000                        NaN
# 23890                             1305.064                   0.020298
# 118812                            1217.663                   0.000000
# 105246                               0.000                        inf
# 122806                             319.016                   0.000000
# 130558                            1073.053                   0.000000
# 18136                              110.196                   0.116320
# 58049                               11.020                   0.000000
# 90851                              978.798                   0.027064
# 86386                              790.289                   3.419015
# 62669                                0.000                        NaN
# 3901                                93.666                   0.000000
# 114325                            2066.170                   0.006204
# 60526                                7.250                 182.691724
# 93701                                0.000                        NaN
# 46982                              464.023                   2.340621
# 81676                              132.235                   0.000000
# 58307                                0.000                        NaN
# 172464                               0.000                        NaN
# ...                                    ...                        ...
# 97863                             1022.301                   0.000000
# 142874                               0.000                        NaN
# 142870                               0.000                        inf
# 24535                              749.331                   5.200155
# 67865                             2385.368                   0.011105
# 67858                              374.665                   2.976408
# 24541                             1203.559                   0.000000
# 142853                               0.000                        NaN
# 142850                               0.000                        NaN
# 142848                               0.000                        NaN
# 142846                               0.000                        NaN
# 67855                              115.705                  13.626032
# 24553                                0.000                        inf
# 142735                            1928.595                   0.013735
# 24559                             1022.301                   0.000000
# 142833                             623.531                   0.000000
# 142832                             877.293                   1.268210
# 142830                             986.252                   0.012997
# 97877                                0.000                        NaN
# 97879                                0.000                        inf
# 142820                             578.527                   0.022156
# 24571                              859.527                   0.000000
# 142818                               5.510                 141.903993
# 142817                               7.250                   0.000000
# 24574                             2972.647                   2.067432
# 142811                             738.311                  10.347211
# 142809                            1065.803                   0.024854
# 67838                                7.250                   3.653793
# 67852                             3349.665                   0.007908
# 143062                             435.021                   0.000000
#
# [172772 rows x 5 columns]

# %% [markdown]
# ## Remove any mutants that have 'inf' or 'NaN'

# %%
data = pd.read_csv('TAG Data.csv')

data = data[['IB' , 'gene' , 'R5-S#11-HLG_WHOLE_normalized_reads' , 'R5-S#11-ALL_WHOLE_normalized_reads']]
data ['Ratios: HLG / ALL (Whole)'] = data ['R5-S#11-HLG_WHOLE_normalized_reads'] / data['R5-S#11-ALL_WHOLE_normalized_reads']

data = data.sort_values('gene')
data = data.replace([np.inf, -np.inf], np.nan)
data = data.dropna()

data
# Out:
#                              IB                           gene  \
# 149875   GAACCCTGGAAATTGCGTCAAT                  Cre01.g000017
# 155091   ACGGGGCCTGGGTCGAGATAAC                  Cre01.g000017
# 151724   AGGTAGGCACTCATAAGGCGCA                  Cre01.g000017
# 119164   GCGTCGCGCTACCTCGTCGTAC                  Cre01.g000017
# 73615    GGGGGGCAATTAGACCTCATTA                  Cre01.g000017
# 27574    CGGACCGGACTACTTGGAGGAA                  Cre01.g000033
# 68558    GACAAATCTGTTTTCACAGACA                  Cre01.g000050
# 60043     CGGACATAGACGGCCGACGAG                  Cre01.g000050
# 23890    TGGGTATCTATGGCTACAGAGT                  Cre01.g000050
# 118812   CACCCGGTTTCAATCGGGCTAG                  Cre01.g000100
# 122806   CTTGGGCGTTGTTCCCCTTACG                  Cre01.g000100
# 130558   TTAGTAATGCTCACAACTATGT                  Cre01.g000100
# 18136    GGGTCGGCACGTCGATGCCACA                  Cre01.g000100
# 58049   GCGTTAATGTGGGGGGGCATCGA                  Cre01.g000100
# 90851    GCAGTCTTGAGTTGTTAGACGT                  Cre01.g000150
# 86386    GAGTGTCGGGCAATTAGTACGG                  Cre01.g000200
# 3901     GTTCCGGAACGGAAGGTACGCG                  Cre01.g000200
# 114325   CTCCCGTGAACTCGCAGCCGGG                  Cre01.g000200
# 60526    TAACTTGCTGTACCGGGTTAAT                  Cre01.g000200
# 46982     GTGTTTGGCTACGTGCGGACT                  Cre01.g000200
# 81676    TGGGACTAGCGCCGGGGTTCGG                  Cre01.g000200
# 18700    TTCTTATGCCATGAGATTCAAT                  Cre01.g000200
# 83100    GGGCGGTTGGTGGCGTCGACAT                  Cre01.g000250
# 102596   TTTACGGTACATGAGTTGCAGG                  Cre01.g000250
# 10906    TCGGACTCAGCCCGTGGCCAAG                  Cre01.g000250
# 53281    CTCTCGATCCGCAGGTAAGGCT                  Cre01.g000250
# 165842   AGCCGAAATCAGGCGTCTCCAC  Cre01.g000250 & Cre01.g000300
# 45915    GGCTCCCCCACGAGGATGCGGG                  Cre01.g000300
# 106356   AGGGCATGTGGTTGACCATTAT                  Cre01.g000300
# 134605   ATGGAGCTGCCTGGGCCAACAC                  Cre01.g000300
# ...                         ...                            ...
# 142751   CAGGCACCTAAGTCAAAGCTAA                  unknown_chrom
# 142748   TTTGGTGCGGAATAACCTCTGT                  unknown_chrom
# 142747   CCGGGCTCTGCGCCTTTCACTA                  unknown_chrom
# 24642    ATATCACGTTTCGTGCCCACGT                  unknown_chrom
# 67810     TTAATGCGAAATTATAAACTC                  unknown_chrom
# 24578    GGTGCATGTTGTAAGGCGAGGC                  unknown_chrom
# 142802   TTTTGTGTGAGCTAGATATCTC                  unknown_chrom
# 24576    GCGTGCGAGGATTCATCGCTAC                  unknown_chrom
# 142807   TAACTGATGTTGGTCGGAGCGG                  unknown_chrom
# 97863    TCGGACGATACTGTTACGCCCA                  unknown_chrom
# 24535    GCCATCGGGGAACGTACGTCCG                  unknown_chrom
# 67865    TCTGTTCCGACATATTGGCCTC                  unknown_chrom
# 67858    GTAACCAGCGGCGCGGTTGCGA                  unknown_chrom
# 24541    CACGTTGTGATAGGTACAGTTC                  unknown_chrom
# 67855    GGGGCTAAGCGTTAGTCGCCCG                  unknown_chrom
# 142735   GCTGTGATTCCCCCGTGGCCTA                  unknown_chrom
# 24559    CACTCTCGTGTCAAAGTTTATT                  unknown_chrom
# 142833   TAAGGGAGGGTTGCCTAGGAGG                  unknown_chrom
# 142832   CTTTGGGTGACAGACTAAAAGA                  unknown_chrom
# 142830   CGCCACGAAGGCGGCTTGGCAG                  unknown_chrom
# 142820    CTCTGAGGGCCGCAACAGTCG                  unknown_chrom
# 24571    TGGTGCGCGGTCTAGGAAGCGG                  unknown_chrom
# 142818   GGGTCAATCGGAGAAGGGGGCG                  unknown_chrom
# 142817    TTGTGATCGCTATCTAGCACT                  unknown_chrom
# 24574    TTGGGTAGGGTGGCAATAAGTG                  unknown_chrom
# 142811   GGAAGCACAGGAGCACGGGCAA                  unknown_chrom
# 142809   GAGAGTGCACCACGGATCCTTT                  unknown_chrom
# 67838    GGTGTTAGACGCATCCCCCCGG                  unknown_chrom
# 67852    TGACGCCGGTGCCTTGGCGCAG                  unknown_chrom
# 143062    TGTAGTTCCTGGCGTTTCAAA                  unknown_chrom
#
#         R5-S#11-HLG_WHOLE_normalized_reads  \
# 149875                             986.977
# 155091                              12.818
# 151724                              64.089
# 119164                               0.000
# 73615                                0.000
# 27574                                0.000
# 68558                             1695.379
# 60043                                0.000
# 23890                               26.490
# 118812                               0.000
# 122806                               0.000
# 130558                               0.000
# 18136                               12.818
# 58049                                0.000
# 90851                               26.490
# 86386                             2702.010
# 3901                                 0.000
# 114325                              12.818
# 60526                             1324.515
# 46982                             1086.102
# 81676                                0.000
# 18700                             1827.830
# 83100                             6808.005
# 102596                            2039.752
# 10906                                0.000
# 53281                                0.000
# 165842                              26.490
# 45915                               38.454
# 106356                            1435.603
# 134605                            1377.495
# ...                                    ...
# 142751                               0.000
# 142748                            1589.417
# 142747                               0.000
# 24642                                0.000
# 67810                             3258.306
# 24578                               25.636
# 142802                               0.000
# 24576                               38.454
# 142807                             715.238
# 97863                                0.000
# 24535                             3896.637
# 67865                               26.490
# 67858                             1115.156
# 24541                                0.000
# 67855                             1576.600
# 142735                              26.490
# 24559                                0.000
# 142833                               0.000
# 142832                            1112.592
# 142830                              12.818
# 142820                              12.818
# 24571                                0.000
# 142818                             781.891
# 142817                               0.000
# 24574                             6145.747
# 142811                            7639.460
# 142809                              26.490
# 67838                               26.490
# 67852                               26.490
# 143062                               0.000
#
#         R5-S#11-ALL_WHOLE_normalized_reads  Ratios: HLG / ALL (Whole)
# 149875                             969.722                   1.017794
# 155091                            3438.106                   0.003728
# 151724                            1002.781                   0.063911
# 119164                            2848.559                   0.000000
# 73615                              536.527                   0.000000
# 27574                              369.156                   0.000000
# 68558                              529.276                   3.203204
# 60043                              837.487                   0.000000
# 23890                             1305.064                   0.020298
# 118812                            1217.663                   0.000000
# 122806                             319.016                   0.000000
# 130558                            1073.053                   0.000000
# 18136                              110.196                   0.116320
# 58049                               11.020                   0.000000
# 90851                              978.798                   0.027064
# 86386                              790.289                   3.419015
# 3901                                93.666                   0.000000
# 114325                            2066.170                   0.006204
# 60526                                7.250                 182.691724
# 46982                              464.023                   2.340621
# 81676                              132.235                   0.000000
# 18700                             1740.086                   1.050425
# 83100                             1645.831                   4.136515
# 102596                             355.268                   5.741446
# 10906                              534.449                   0.000000
# 53281                              710.762                   0.000000
# 165842                             623.531                   0.042484
# 45915                              352.626                   0.109050
# 106356                             495.881                   2.895055
# 134605                             732.286                   1.881089
# ...                                    ...                        ...
# 142751                            1449.074                   0.000000
# 142748                            1442.821                   1.101604
# 142747                             833.791                   0.000000
# 24642                                7.250                   0.000000
# 67810                             1515.325                   2.150236
# 24578                             1504.171                   0.017043
# 142802                             790.289                   0.000000
# 24576                              595.057                   0.064622
# 142807                               7.250                  98.653517
# 97863                             1022.301                   0.000000
# 24535                              749.331                   5.200155
# 67865                             2385.368                   0.011105
# 67858                              374.665                   2.976408
# 24541                             1203.559                   0.000000
# 67855                              115.705                  13.626032
# 142735                            1928.595                   0.013735
# 24559                             1022.301                   0.000000
# 142833                             623.531                   0.000000
# 142832                             877.293                   1.268210
# 142830                             986.252                   0.012997
# 142820                             578.527                   0.022156
# 24571                              859.527                   0.000000
# 142818                               5.510                 141.903993
# 142817                               7.250                   0.000000
# 24574                             2972.647                   2.067432
# 142811                             738.311                  10.347211
# 142809                            1065.803                   0.024854
# 67838                                7.250                   3.653793
# 67852                             3349.665                   0.007908
# 143062                             435.021                   0.000000
#
# [130672 rows x 5 columns]

# %% [markdown]
# ## Get unique genes

# %%
data = pd.read_csv('TAG Data.csv')

data = data[['IB' , 'gene' , 'R5-S#11-HLG_WHOLE_normalized_reads' , 'R5-S#11-ALL_WHOLE_normalized_reads']]
data ['Ratios: HLG / ALL (Whole)'] = data ['R5-S#11-HLG_WHOLE_normalized_reads'] / data['R5-S#11-ALL_WHOLE_normalized_reads']

data = data.sort_values('gene')
data = data.replace([np.inf, -np.inf], np.nan)
data = data.dropna()
data = data.gene.unique()

data = pd.DataFrame(data)

data.rename(columns = {'0':'Unique Genes'}, inplace = True)

data
# Out:
#                                    0
# 0                      Cre01.g000017
# 1                      Cre01.g000033
# 2                      Cre01.g000050
# 3                      Cre01.g000100
# 4                      Cre01.g000150
# 5                      Cre01.g000200
# 6                      Cre01.g000250
# 7      Cre01.g000250 & Cre01.g000300
# 8                      Cre01.g000300
# 9                      Cre01.g000350
# 10                     Cre01.g000400
# 11                     Cre01.g000450
# 12                     Cre01.g000500
# 13                     Cre01.g000550
# 14                     Cre01.g000600
# 15                     Cre01.g000650
# 16                     Cre01.g000700
# 17     Cre01.g000700 & Cre01.g000750
# 18                     Cre01.g000750
# 19     Cre01.g000750 & Cre01.g000800
# 20                     Cre01.g000800
# 21                     Cre01.g000850
# 22                     Cre01.g000900
# 23     Cre01.g000900 & Cre01.g000950
# 24                     Cre01.g000950
# 25                     Cre01.g001000
# 26     Cre01.g001000 & Cre01.g001100
# 27                     Cre01.g001100
# 28                     Cre01.g001150
# 29                     Cre01.g001200
# ...                              ...
# 20220                  Cre36.g759747
# 20221                  Cre38.g759997
# 20222                  Cre39.g760047
# 20223                  Cre39.g760097
# 20224                  Cre40.g760147
# 20225  Cre40.g760147 & Cre40.g760197
# 20226                  Cre40.g760197
# 20227                  Cre40.g760247
# 20228                  Cre41.g760297
# 20229                  Cre43.g760497
# 20230  Cre43.g760497 & Cre43.g760547
# 20231                  Cre43.g760547
# 20232  Cre43.g760547 & Cre43.g760597
# 20233                  Cre43.g760597
# 20234                  Cre46.g760947
# 20235                  Cre46.g761047
# 20236                  Cre47.g761097
# 20237  Cre48.g761147 & Cre48.g761197
# 20238                  Cre49.g761297
# 20239  Cre49.g761297 & Cre49.g761347
# 20240                  Cre49.g761347
# 20241                  Cre50.g761397
# 20242                  Cre50.g761447
# 20243  Cre50.g761447 & Cre50.g761497
# 20244                  Cre50.g761497
# 20245                  Cre51.g761597
# 20246                  Cre52.g761647
# 20247                   gene_unknown
# 20248                  no_gene_found
# 20249                  unknown_chrom
#
# [20250 rows x 1 columns]

# %% [markdown]
# ## Results of GroupBy mean, median, and count. Then reorder by descending value of 'Ratio Median'

# %%
data = pd.read_csv('TAG Data.csv')

data = data[['gene' , 'R5-S#11-HLG_WHOLE_normalized_reads' , 'R5-S#11-ALL_WHOLE_normalized_reads']]
data ['Ratios: HLG / ALL (Whole)'] = data ['R5-S#11-HLG_WHOLE_normalized_reads'] / data['R5-S#11-ALL_WHOLE_normalized_reads']

data = data.sort_values('gene')
data = data.replace([np.inf, -np.inf], np.nan)
data = data.dropna()

data = data.drop(['R5-S#11-HLG_WHOLE_normalized_reads' , 'R5-S#11-ALL_WHOLE_normalized_reads'], axis = 1)

data = pd.DataFrame(data)

mean = data.groupby(['gene']).mean()
mean.rename(columns = {'Ratios: HLG / ALL (Whole)': 'Ratio Mean'}, inplace = True)
# mean

median = data.groupby(['gene']).median()
median.rename(columns = {'Ratios: HLG / ALL (Whole)': 'Ratio Median'}, inplace = True)
# median

count = data.groupby(['gene']).count()
count.rename(columns = {'Ratios: HLG / ALL (Whole)': 'Count'}, inplace = True)
# count

result = data.reset_index(drop = True)
result = pd.concat([mean, median, count], axis = 1)

result = result.sort_values(by = ['Ratio Median'], ascending = False)

result
# Out:
#                                 Ratio Mean  Ratio Median  Count
# gene
# Cre06.g249050                  1900.582940   1900.582940      1
# Cre17.g726400                  1330.640744   1330.640744      2
# Cre10.g418626 & Cre10.g418650  1293.456966   1293.456966      1
# Cre07.g350300                  1014.275293   1014.275293      2
# Cre09.g396100 & Cre09.g396050  1004.959347   1004.959347      1
# Cre01.g040400                   965.412341    965.412341      1
# Cre10.g445153 & Cre10.g445151   849.097641    849.097641      1
# Cre09.g399141 & Cre09.g399178   832.813612    832.813612      2
# Cre01.g026200                   825.620668    825.620668      2
# Cre17.g696800 & Cre17.g696850   644.383666    644.383666      1
# Cre12.g508750 & Cre12.g508700   624.805517    624.805517      1
# Cre10.g427400                   586.226316    586.226316      2
# Cre10.g459650                   556.039874    556.039874      2
# Cre02.g104850                   544.421103    544.421103      1
# Cre05.g241639                   542.026724    542.026724      2
# Cre07.g312833                   539.700363    539.700363      1
# Cre07.g317576 & Cre07.g317601   507.493409    507.493409      2
# Cre06.g278269 & Cre06.g278270   493.267448    493.267448      1
# Cre12.g540150                   492.615318    492.615318      1
# Cre07.g322700                   489.685118    489.685118      1
# Cre08.g377950 & Cre08.g378000   483.869328    483.869328      1
# Cre17.g731600                   471.096174    471.096174      2
# Cre01.g015250 & Cre01.g015300   467.585299    467.585299      1
# Cre06.g300650                   456.729103    456.729103      1
# Cre17.g708050 & Cre17.g708076   453.627586    453.627586      1
# Cre12.g484550                   452.940639    452.940639      2
# Cre08.g363050 & Cre08.g363100   440.875592    440.875592      1
# Cre09.g396150                   431.152276    431.152276      1
# Cre09.g400145                   429.213964    429.213964      2
# Cre03.g202700 & Cre03.g202650   421.059347    421.059347      1
# ...                                    ...           ...    ...
# Cre13.g566700 & Cre13.g566750     0.000000      0.000000      1
# Cre07.g332025 & Cre07.g332050     0.000000      0.000000      2
# Cre07.g332066 & Cre07.g332084     0.000000      0.000000      4
# Cre13.g567626 & Cre13.g567650     0.000000      0.000000      1
# Cre07.g329650                     0.000000      0.000000      1
# Cre07.g329600                     0.124184      0.000000      3
# Cre07.g328075                     0.000000      0.000000      1
# Cre07.g327050                     0.940912      0.000000      6
# Cre07.g327200                    62.845931      0.000000      5
# Cre07.g327226                     0.016066      0.000000      7
# Cre07.g327333                     0.000000      0.000000      1
# Cre07.g327450                     0.014852      0.000000      6
# Cre07.g327950                     3.171321      0.000000     10
# Cre13.g568400                     0.694678      0.000000      3
# Cre13.g568350                     0.000000      0.000000      3
# Cre07.g327976 & Cre07.g328000     0.000000      0.000000      1
# Cre07.g328050 & Cre07.g328075     0.000000      0.000000      1
# Cre13.g568176 & Cre13.g568200     0.000000      0.000000      1
# Cre07.g329500                     0.013940      0.000000      7
# Cre07.g328150                     1.253600      0.000000      8
# Cre13.g568150 & Cre13.g568176     0.000000      0.000000      1
# Cre13.g568100                     4.529647      0.000000      5
# Cre07.g328226                     0.581579      0.000000      4
# Cre07.g328600                    11.438132      0.000000      3
# Cre07.g329050 & Cre07.g329100     0.025285      0.000000      3
# Cre07.g329400                     0.000000      0.000000      1
# Cre07.g329476 & Cre07.g329500     0.000000      0.000000      1
# Cre13.g567800                     0.000000      0.000000      1
# Cre13.g567750 & Cre13.g567800     0.000000      0.000000      1
# Cre06.g259000 & Cre06.g259050     0.000000      0.000000      1
#
# [20250 rows x 3 columns]

# %% [markdown]
# ## As the 'Ratio Median' decreases, genes with 'Counts'   ≥ 3 are left

# %%
data = pd.read_csv('TAG Data.csv')

data = data[['gene' , 'R5-S#11-HLG_WHOLE_normalized_reads' , 'R5-S#11-ALL_WHOLE_normalized_reads']]
data ['Ratios: HLG / ALL (Whole)'] = data ['R5-S#11-HLG_WHOLE_normalized_reads'] / data['R5-S#11-ALL_WHOLE_normalized_reads']

data = data.sort_values('gene')
data = data.replace([np.inf, -np.inf], np.nan)
data = data.dropna()

data = data.drop(['R5-S#11-HLG_WHOLE_normalized_reads' , 'R5-S#11-ALL_WHOLE_normalized_reads'], axis = 1)

data = pd.DataFrame(data)

mean = data.groupby(['gene']).mean()
mean.rename(columns = {'Ratios: HLG / ALL (Whole)': 'Ratio Mean'}, inplace = True)
# mean

median = data.groupby(['gene']).median()
median.rename(columns = {'Ratios: HLG / ALL (Whole)': 'Ratio Median'}, inplace = True)
# median

count = data.groupby(['gene']).count()
count.rename(columns = {'Ratios: HLG / ALL (Whole)': 'Count'}, inplace = True)
# count

result = data.reset_index(drop = True)
result = pd.concat([mean, median, count], axis = 1)

result = result.sort_values(by = ['Ratio Median'], ascending = False)

greater = result[result['Count'] < 3].index
result.drop(greater, inplace = True)

result
# Out:
#                                Ratio Mean  Ratio Median  Count
# gene
# Cre08.g369667                  135.725560    200.061343      3
# Cre01.g022850                  251.301438    183.901154      3
# Cre08.g363400                  227.408470    172.145826      4
# Cre09.g402849                  187.263174    168.649261      4
# Cre08.g361350                  104.587676     95.906524      4
# Cre10.g450550                  105.049441     95.003159      4
# Cre04.g214502                  101.443078     87.303571      4
# Cre16.g676650 & Cre16.g676600  277.691345     78.557448      4
# Cre12.g488600                   86.361087     62.346982      3
# Cre06.g282300 & Cre06.g282350   85.861118     56.634414      4
# Cre07.g329700 & Cre07.g329750   40.439052     54.807448      3
# Cre09.g402041 & Cre09.g405100   59.719995     52.748841      4
# Cre02.g105050                  104.392491     47.107486      4
# Cre03.g148950                  126.340550     42.851605      6
# Cre16.g660390                  170.766060     41.873321      3
# Cre16.g665950                   69.999255     41.268077      3
# Cre06.g271500 & Cre06.g271526   67.491526     40.365944      3
# Cre09.g395102                   28.310012     38.383848      3
# Cre11.g477900                   93.775423     34.023617      5
# Cre07.g349900                  163.907034     33.680481      4
# Cre05.g241650                   60.784954     30.844409      4
# Cre10.g441400 & Cre10.g441450   34.901695     29.806663      3
# Cre04.g231124 & Cre04.g231222  147.170246     27.401834      3
# Cre01.g028450                   59.189018     26.489380      4
# Cre13.g577500                   58.175390     26.293015      8
# Cre12.g542202                   96.138463     19.848517      3
# Cre09.g400850 & Cre09.g400851   96.339323     18.206504      4
# Cre17.g697750                   45.444048     17.803033      4
# Cre09.g390615 & Cre09.g390652   13.633012     16.500374      3
# Cre16.g692901                   84.526695     15.592424      4
# ...                                   ...           ...    ...
# Cre13.g570650                   43.750663      0.000000      5
# Cre07.g325728                    0.409236      0.000000      6
# Cre13.g568700                    0.118785      0.000000     10
# Cre07.g329783                    0.001803      0.000000      3
# Cre13.g567550 & Cre13.g567600    0.307126      0.000000      5
# Cre13.g567550                    0.004006      0.000000      4
# Cre07.g329900 & Cre07.g329950    0.107432      0.000000      7
# Cre07.g330100                    0.009717      0.000000      4
# Cre07.g330150                    0.014496      0.000000      6
# Cre07.g330550                    1.379489      0.000000      4
# Cre13.g567327                    0.157609      0.000000      3
# Cre07.g330700 & Cre07.g330750    0.292670      0.000000      3
# Cre07.g331100                    4.915820      0.000000      3
# Cre13.g567150                    2.841732      0.000000      3
# Cre13.g567100                    0.614848      0.000000      3
# Cre07.g332066 & Cre07.g332084    0.000000      0.000000      4
# Cre07.g329600                    0.124184      0.000000      3
# Cre07.g327050                    0.940912      0.000000      6
# Cre07.g327200                   62.845931      0.000000      5
# Cre07.g327226                    0.016066      0.000000      7
# Cre07.g327450                    0.014852      0.000000      6
# Cre07.g327950                    3.171321      0.000000     10
# Cre13.g568400                    0.694678      0.000000      3
# Cre13.g568350                    0.000000      0.000000      3
# Cre07.g329500                    0.013940      0.000000      7
# Cre07.g328150                    1.253600      0.000000      8
# Cre13.g568100                    4.529647      0.000000      5
# Cre07.g328226                    0.581579      0.000000      4
# Cre07.g328600                   11.438132      0.000000      3
# Cre07.g329050 & Cre07.g329100    0.025285      0.000000      3
#
# [11621 rows x 3 columns]
